# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.fftpack import fft, fftshift
from suaBibSignal import *
import numpy as np
import sounddevice as sd
import matplotlib.pyplot as plt
import soundfile   as sf
import peakutils
from soundUtils import *

# %%
mysound = record_audio(3)
plt.figure()
plt.xlim(65000,66000)
plt.title("sinal gravado")
plt.grid()
plt.plot(mysound[:,1])
plt.show()
freqs = calc_peaks(mysound)
# Out:
# recording shape: (132300, 2)

# %%
freqs
# Out:
# array([ 852.50644374, 1209.17580632])

# %%
my_char = match_char(freqs[:2])
print(f'sinal identificado: {my_char}')
# Out:
# sinal identificado: 7

# %%
wave = Wave(my_char)
wave.plot()
