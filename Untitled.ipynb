# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.fftpack import fft, fftshift
from suaBibSignal import *
import numpy as np
import sounddevice as sd
import matplotlib.pyplot as plt
import soundfile   as sf
import peakutils
from soundUtils import *

# %%
mysound = record_audio(3)
# Out:
# recording shape: (132300, 2)

# %%
plt.figure()
plt.xlim(1000,2000)
plt.plot(mysound[:,1])
plt.show()

# %%
sd.play(mysound)
sd.wait()

# %%
calc_peaks(mysound, thres=0.5, min_dist=50)
# Out:
# array([-3483.92717232, -2090.75885624,  -771.3918957 ,  -748.24510691,
#         -718.38910399,  -688.86856178,   689.20402249,   718.7245647 ,
#          748.58056762,   771.7273564 ,  2091.09431695,  3484.26263302])
